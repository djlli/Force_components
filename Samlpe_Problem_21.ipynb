# %%
import handcalcs.render
import forallpeople as si
si.environment('default', top_level=False)
from math import cos, sin, pi, degrees, radians, sqrt, atan

# %% [markdown]
# # Statics book
# ## Sample Problem 2/1 p. 29

# %% [markdown]
# Determine componets of the force $ F_1, F_2 $ and $ F_3 $
# $ \alpha = 35 ^\circ $

# %% [markdown]
# ![](Sample_Problem_2-1.png)

# %% [markdown]
# ## Calculate F1

# %%
# %%render 1
# alpha = radians(35) # Input in degrees
# F_1 = 600 * si.N
#
# F_1x = F_1 * cos(alpha)
# F_1Y = F_1 * sin(alpha)

# %% [markdown]
# ## Calculate F2

# %%
# %%render 0
#
# ratio = 3/4
# mod = (3 * si.m)
# hos = (4 * si.m)
# hyp = (mod**2 + hos**2)**0.5
# F_2 = (500 * si.N)
#
# F_2x = F_2 * hos/hyp
# F_2y = F_2 * mod/hyp

# %% [markdown]
# ## Calculate F3

# %%
# %%render 1
#
# x1 = (0.2 * si.m)
# x2 = (0.4 * si.m)
#
# y1 = (0.1 * si.m)
# y2 = (0.3 * si.m)
#
# F_3 = 800 * si.N
#
# Delta_x = x2-x1
# Delta_y = y2+y1
#
# beta = atan (Delta_y / Delta_x)
#
# F_3x = F_3 * cos(beta)
# F_3y = -F_3 * sin(beta)
